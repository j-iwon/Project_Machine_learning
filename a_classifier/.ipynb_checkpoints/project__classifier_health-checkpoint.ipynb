# %% [markdown]
# ## **💊의료 예측 모델**

# %% [markdown]
# **Feature**
#
# > **Name**: 의료 기록과 관련된 환자의 이름.
# > **Age**: 입원 당시 환자의 나이. (세로 표시)
# > **Gender**: 환자의 성별. (남성 또는 여성)
# > **Blood Type**: 환자의 혈액형으로 일반적인 혈액형(A,B,AB,O)에 +와 -로 나타남.
# > **Medical Condition**: 의학적 상태. 당뇨병, 고혈압, 천식등 환자와 관련된 주요 의학적 상태 또는 진단을 나타냄.
# > **Date of Admission**: 입원 날짜.
# > **Doctor**: 환자의 진료를 담당한 의사.
# > **Hospital**: 환자가 입원한 의료시설.
# > **Insurance Provider**: 보험제공자.  "Aetna", "Blue Cross", "Cigna", "UnitedHealthcare" 및 "Medicare"를 포함한 여러 옵션 중 하나.
# > **Billing Amount**: 청구 금액.
# > **Room Number**: 병실 번호.
# > **Admission Type**: 입원 유형. Emergency(응급), Elective(선택), Urgent(긴급)의 유형이 있음.
# > **Discharge Date**: 퇴원일
# > **Medication**: 입원중 환자에게 처방되거나 투여된 약물. 아스피린, 이부프로펜, 페니실린, 파라세타몰, 리피토 등.
#
# **Target**
#
# > **Test Results**: 의료 검사 결과. Normal(정상), Abnormal(비정상), Inconclusive(불확실함).

# %% [markdown]
# #### **🚑 데이터 탐색**

# %%
import pandas as pd

healthcare_df = pd.read_csv('./datasets/healthcare_dataset.csv')
healthcare_df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# 0           2022-11-17     Patrick Parker           Wallace-Hamilton
# 1           2023-06-01      Diane Jackson  Burke, Griffin and Cooper
# 2           2019-01-09         Paul Baker                 Walton LLC
# 3           2020-05-02     Brian Chandler                 Garcia Ltd
# 4           2021-07-09     Dustin Griffin    Jones, Brown and Murray
# ...                ...                ...                        ...
# 9995        2022-07-29       Samuel Moody   Wood, Martin and Simmons
# 9996        2022-01-06  Christopher Yates               Nash-Krueger
# 9997        2022-07-01   Robert Nicholson            Larson and Sons
# 9998        2020-02-06        Jamie Lewis               Wilson-Lyons
# 9999        2023-03-22        Tasha Avila  Torres, Young and Stewart
#
#      Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0              Medicare    37490.983364          146       Elective
# 1      UnitedHealthcare    47304.064845          404      Emergency
# 2              Medicare    36874.896997          292      Emergency
# 3              Medicare    23303.322092          480         Urgent
# 4      UnitedHealthcare    18086.344184          477         Urgent
# ...                 ...             ...          ...            ...
# 9995   UnitedHealthcare    39606.840083          110       Elective
# 9996         Blue Cross     5995.717488          244      Emergency
# 9997         Blue Cross    49559.202905          312       Elective
# 9998   UnitedHealthcare    25236.344761          420         Urgent
# 9999              Aetna    37223.965865          290      Emergency
#
#      Discharge Date   Medication  Test Results
# 0        2022-12-01      Aspirin  Inconclusive
# 1        2023-06-15      Lipitor        Normal
# 2        2019-02-08      Lipitor        Normal
# 3        2020-05-03   Penicillin      Abnormal
# 4        2021-08-02  Paracetamol        Normal
# ...             ...          ...           ...
# 9995     2022-08-02    Ibuprofen      Abnormal
# 9996     2022-01-29    Ibuprofen        Normal
# 9997     2022-07-15    Ibuprofen        Normal
# 9998     2020-02-26   Penicillin        Normal
# 9999     2023-04-15   Penicillin      Abnormal
#
# [10000 rows x 15 columns]

# %%
healthcare_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.1+ MB

# %%
# 결측치 검사
healthcare_df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
# 중복행 검사
healthcare_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### **🚑 데이터 전처리**

# %%
# 데이터 복사
h_df = healthcare_df.copy()

# %%
# 불필요한 컬럼 제거
h_df.drop(labels=['Name',
                  'Doctor',
                  'Hospital',
                  'Room Number',
                  'Date of Admission',
                  'Discharge Date',
                  'Insurance Provider',
                  'Room Number',
                  'Billing Amount'], axis=1, inplace=True)
display(h_df)
# Out:
#       Age  Gender Blood Type Medical Condition Admission Type   Medication  \
# 0      81  Female         O-          Diabetes       Elective      Aspirin
# 1      35    Male         O+            Asthma      Emergency      Lipitor
# 2      61    Male         B-           Obesity      Emergency      Lipitor
# 3      49    Male         B-            Asthma         Urgent   Penicillin
# 4      51    Male         O-         Arthritis         Urgent  Paracetamol
# ...   ...     ...        ...               ...            ...          ...
# 9995   83    Male         A+           Obesity       Elective    Ibuprofen
# 9996   47  Female        AB+         Arthritis      Emergency    Ibuprofen
# 9997   54    Male         B-         Arthritis       Elective    Ibuprofen
# 9998   84    Male         A+         Arthritis         Urgent   Penicillin
# 9999   20    Male         B-         Arthritis      Emergency   Penicillin
#
#       Test Results
# 0     Inconclusive
# 1           Normal
# 2           Normal
# 3         Abnormal
# 4           Normal
# ...            ...
# 9995      Abnormal
# 9996        Normal
# 9997        Normal
# 9998        Normal
# 9999      Abnormal
#
# [10000 rows x 7 columns]

# %%
# target value 확인
h_df['Test Results'].value_counts()
# Out:
# Test Results
# Abnormal        3456
# Inconclusive    3277
# Normal          3267
# Name: count, dtype: int64

# %%
# feature value 확인
h_df['Medical Condition'].value_counts()
# Out:
# Medical Condition
# Asthma          1708
# Cancer          1703
# Hypertension    1688
# Arthritis       1650
# Obesity         1628
# Diabetes        1623
# Name: count, dtype: int64

# %%
h_df['Blood Type'] = h_df['Blood Type'].apply(lambda x: x[:-1] if x[-1] in ['+', '-'] else x)

# %%
h_df['Blood Type'].value_counts()
# Out:
# Blood Type
# AB    2533
# B     2496
# O     2492
# A     2479
# Name: count, dtype: int64

# %%
# 문자열 데이터 변환
from sklearn.preprocessing import LabelEncoder

gender_encoder = LabelEncoder()
genders = gender_encoder.fit_transform(h_df['Gender'].tolist())
h_df['Gender'] = genders

blood_encoder = LabelEncoder()
bloods = blood_encoder.fit_transform(h_df['Blood Type'].tolist())
h_df['Blood Type'] = bloods

medical_encoder = LabelEncoder()
medicals = medical_encoder.fit_transform(h_df['Medical Condition'].tolist())
h_df['Medical Condition'] = medicals

admission_encoder = LabelEncoder()
admissions = admission_encoder.fit_transform(h_df['Admission Type'].tolist())
h_df['Admission Type'] = admissions

medication_encoder = LabelEncoder()
medications = medication_encoder.fit_transform(h_df['Medication'].tolist())
h_df['Medication'] = medications

result_encoder = LabelEncoder()
results = result_encoder.fit_transform(h_df['Test Results'].tolist())
h_df['Test Results'] = results

# %%
h_df
# Out:
#       Age  Gender  Blood Type  Medical Condition  Admission Type  Medication  \
# 0      81       0           3                  3               0           0
# 1      35       1           3                  1               1           2
# 2      61       1           2                  5               1           2
# 3      49       1           2                  1               2           4
# 4      51       1           3                  0               2           3
# ...   ...     ...         ...                ...             ...         ...
# 9995   83       1           0                  5               0           1
# 9996   47       0           1                  0               1           1
# 9997   54       1           2                  0               0           1
# 9998   84       1           0                  0               2           4
# 9999   20       1           2                  0               1           4
#
#       Test Results
# 0                1
# 1                2
# 2                2
# 3                0
# 4                2
# ...            ...
# 9995             0
# 9996             2
# 9997             2
# 9998             2
# 9999             0
#
# [10000 rows x 7 columns]

# %%
# 데이터프레임의 열 이름 확인
print(h_df.columns)
# Out:
# Index(['Age', 'Gender', 'Blood Type', 'Medical Condition', 'Admission Type',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
h_df.describe().T
# Out:
#                      count     mean        std   min   25%   50%   75%   max
# Age                10000.0  51.4522  19.588974  18.0  35.0  52.0  68.0  85.0
# Gender             10000.0   0.4925   0.499969   0.0   0.0   0.0   1.0   1.0
# Blood Type         10000.0   1.5001   1.115493   0.0   1.0   1.0   2.0   3.0
# Medical Condition  10000.0   2.4875   1.701803   0.0   1.0   2.0   4.0   5.0
# Admission Type     10000.0   1.0149   0.814337   0.0   0.0   1.0   2.0   2.0
# Medication         10000.0   2.0208   1.418580   0.0   1.0   2.0   3.0   4.0
# Test Results       10000.0   0.9811   0.819762   0.0   0.0   1.0   2.0   2.0

# %%
# 이상치 확인
import numpy as np
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

features = ['Age']

total_count = h_df.shape[0]
for feature in features:
    std_df = std.fit_transform(h_df[[feature]])
    count = ((std_df < -1.96) | (std_df > 1.96)).sum()
    print(f'{feature}: {count}건, {np.round(count / total_count * 100, 4)}%')
# Out:
# Age: 0건, 0.0%

# %%
import matplotlib.pyplot as plt
# 컬러맵 가져오기
cmap = plt.get_cmap('Pastel2')
# 컬러맵의 색상 선택
all_colors = cmap(np.array([0,4]))
# 히스토그램 그려보기
h_df.hist(figsize=(7, 7), color=cmap(np.array([1])))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Blood Type'}>],
#        [<Axes: title={'center': 'Medical Condition'}>,
#         <Axes: title={'center': 'Admission Type'}>,
#         <Axes: title={'center': 'Medication'}>],
#        [<Axes: title={'center': 'Test Results'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# 데이터프레임의 상관관계
import seaborn as sns
import matplotlib.pyplot as plt

corr = h_df.corr()
fig = plt.figure(figsize=(7, 5))
heatmap = sns.heatmap(corr, cmap="Oranges")
heatmap.set_title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
# 타겟 언더샘플링 및 데이터 분리
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

features, targets = h_df.iloc[:, :-1], h_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

y_train_over.value_counts()
# Out:
# Test Results
# 1    2745
# 0    2745
# 2    2745
# Name: count, dtype: int64

# %%
# 피처와 타겟의 상관관계 값을 확인
corr[['Test Results']].sort_values(by="Test Results", ascending=False)[1:]
# Out:
#                    Test Results
# Age                    0.008747
# Medical Condition      0.001659
# Blood Type            -0.001584
# Gender                -0.010472
# Admission Type        -0.010964
# Medication            -0.013938

# %%
# 하이퍼파라미터 조정 없이 dtc를 훈련한 후 피쳐별 중요도 확인하기
from sklearn.tree import DecisionTreeClassifier
dtc =  DecisionTreeClassifier()
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz

# 파일 내보내기
export_graphviz(
    dtc, 
    out_file='./images/health_dtc01.dot',
    class_names = [str(class_) for class_ in result_encoder.classes_],
    feature_names=features.columns, 
    impurity=True, 
    filled=True
)

# %%
import graphviz

with open('./images/health_dtc01.dot') as f:
    health_dtc01 = f.read()

health_dtc01_graph = graphviz.Source(health_dtc01)

# %%
health_dtc01_graph.render(filename='health_dtc01', directory='./images', format='png')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.0896657 to fit
# 'images\\health_dtc01.png'

# %% [markdown]
# <img src="./images/health_dtc01.png">

# %%
# 피쳐별 중요도
import matplotlib.pyplot as plt
import seaborn as sns

class_names = targets.unique().astype(str).tolist()
feature_names = features.columns.tolist()

for name, value in zip(feature_names, dtc.feature_importances_):
        print(f'{name}: {round(value * 100, 2)}%')
# Out:
# Age: 40.43%
# Gender: 6.44%
# Blood Type: 11.7%
# Medical Condition: 19.75%
# Admission Type: 10.15%
# Medication: 11.54%

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=dtc.feature_importances_, y=features.columns)
plt.show()

# %%
import numpy as np

# Classifier의 Decision Boundary를 시각화 하는 함수
def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start , xlim_end = ax.get_xlim()
    ylim_start , ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 . 
    model.fit(X.values, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행. 
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행. 
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow',
                           zorder=1)

# %%
# 전체 행의 특정 데이터 선택하여 피처로 지정, 타겟 데이터를 타겟으로 지정
features_d, targets_d = h_df.iloc[:, [0, 3]], h_df.iloc[:, -1]
features_d
# Out:
#       Age  Medical Condition
# 0      81                  3
# 1      35                  1
# 2      61                  5
# 3      49                  1
# 4      51                  0
# ...   ...                ...
# 9995   83                  5
# 9996   47                  0
# 9997   54                  0
# 9998   84                  0
# 9999   20                  0
#
# [10000 rows x 2 columns]

# %%
# 데이터 학습
dtc.fit(features_d, targets_d)

# 시각화 함수를 통해 데이터 시각화
visualize_boundary(dtc, features_d, targets_d)

# %%
# 결정 트리의 무작위성을 제어하고 분류 모델 담기
dtc = DecisionTreeClassifier(random_state=124, min_samples_leaf=60)

# 데이터 학습
dtc.fit(features_d, targets_d)

# 시각화 함수를 통해 데이터 시각화
visualize_boundary(dtc, features_d, targets_d)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


dtc_parameters = {'max_depth': [10, 20, 30], 'min_samples_split': [60, 70, 80]}
l_svc_parameters = {'C': [0.001, 0.01, 0.1]}
knn_parameters = {'n_neighbors': [3, 5, 7, 9, 11]}

dtc = DecisionTreeClassifier()
l_svc = LinearSVC(verbose=True)
knn = KNeighborsClassifier()

g_dtc = GridSearchCV(dtc, param_grid=dtc_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_l_svc = GridSearchCV(l_svc, param_grid=l_svc_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_knn = GridSearchCV(knn, param_grid=knn_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)

# %%
g_dtc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 30],
#                          'min_samples_split': [60, 70, 80]},
#              return_train_score=True)

# %%
g_l_svc.fit(X_train_over, y_train_over)
# Out:
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=3, estimator=LinearSVC(verbose=True), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1]}, return_train_score=True)

# %%
g_knn.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11]},
#              return_train_score=True)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='macro')
    recall = recall_score(y_test , prediction, average='macro')
    f1 = f1_score(y_test, prediction, average='macro')
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %% [markdown]
# ### **🚑 DTC**

# %%
dtc_result_df = pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(dtc_result_df)

dtc = g_dtc.best_estimator_
# Out:
#                                        params  mean_test_score  \
# 0  {'max_depth': 10, 'min_samples_split': 60}         0.339041
# 1  {'max_depth': 10, 'min_samples_split': 70}         0.336126
# 2  {'max_depth': 10, 'min_samples_split': 80}         0.334305
# 3  {'max_depth': 20, 'min_samples_split': 60}         0.342077
# 4  {'max_depth': 20, 'min_samples_split': 70}         0.338555
# 5  {'max_depth': 20, 'min_samples_split': 80}         0.337219
# 6  {'max_depth': 30, 'min_samples_split': 60}         0.342077
# 7  {'max_depth': 30, 'min_samples_split': 70}         0.338434
# 8  {'max_depth': 30, 'min_samples_split': 80}         0.337341
#
#    rank_test_score
# 0                3
# 1                8
# 2                9
# 3                1
# 4                4
# 5                7
# 6                1
# 7                5
# 8                6

# %%
prediction = dtc.predict(X_test)

# %%
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[224 238 249]
#  [209 236 208]
#  [201 214 221]]
# 정확도: 0.3405, 정밀도: 0.3408, 재현율: 0.3413, F1: 0.3405
# ################################################################################

# %% [markdown]
# ### **🚑 SVC**

# %%
l_svc_result_df = pd.DataFrame(g_l_svc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(l_svc_result_df)
# Out:
#          params  mean_test_score  rank_test_score
# 0  {'C': 0.001}         0.338191                2
# 1   {'C': 0.01}         0.338191                2
# 2    {'C': 0.1}         0.338676                1

# %%
svc = g_l_svc.best_estimator_
prediction = g_l_svc.predict(X_test)

# %%
get_evaluation(y_test, prediction, svc, X_test)
# Out:
# 오차 행렬
# [[  8 348 355]
#  [  3 313 337]
#  [  5 320 311]]
# 정확도: 0.3160, 정밀도: 0.3764, 재현율: 0.3265, F1: 0.2615
# ################################################################################

# %% [markdown]
# ### **🚑 KNN**

# %%
result_df = pd.DataFrame(g_knn.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                 params  mean_test_score  rank_test_score
# 0   {'n_neighbors': 3}         0.341591                5
# 1   {'n_neighbors': 5}         0.350091                1
# 2   {'n_neighbors': 7}         0.349120                2
# 3   {'n_neighbors': 9}         0.348998                3
# 4  {'n_neighbors': 11}         0.346205                4

# %%
knn_c = g_knn.best_estimator_
prediction = knn_c.predict(X_test)

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[331 228 152]
#  [300 207 146]
#  [278 200 158]]
# 정확도: 0.3480, 정밀도: 0.3455, 재현율: 0.3437, F1: 0.3398
# ################################################################################

# %% [markdown]
# #### 📊 1Cycle 결과
# 정확도가 낮게 나와 학습이 충분하지 않다고 판단되었습니다.
# 하이퍼 파라미터를 조정하여 데이터 품질 개선과 모델 기능 향상이 필요합니다.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


dtc_parameters = {'max_depth': [20, 30, 40], 'min_samples_split': [40, 50, 60]}
l_svc_parameters = {'C': [0.01, 0.1, 1, 10, 100]}
knn_parameters = {'n_neighbors': [3, 5, 7, 9, 11]}

dtc = DecisionTreeClassifier()
l_svc = LinearSVC(verbose=True)
knn = KNeighborsClassifier()

g_dtc = GridSearchCV(dtc, param_grid=dtc_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_l_svc = GridSearchCV(l_svc, param_grid=l_svc_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_knn = GridSearchCV(knn, param_grid=knn_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)

# %%
g_dtc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [20, 30, 40],
#                          'min_samples_split': [40, 50, 60]},
#              return_train_score=True)

# %%
g_l_svc.fit(X_train_over, y_train_over)
# Out:
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=3, estimator=LinearSVC(verbose=True), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100]},
#              return_train_score=True)

# %%
g_knn.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11]},
#              return_train_score=True)

# %% [markdown]
# ### **🚑 DTC**

# %%
dtc_result_df = pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(dtc_result_df)

dtc = g_dtc.best_estimator_
# Out:
#                                        params  mean_test_score  \
# 0  {'max_depth': 20, 'min_samples_split': 40}         0.345477
# 1  {'max_depth': 20, 'min_samples_split': 50}         0.344748
# 2  {'max_depth': 20, 'min_samples_split': 60}         0.341955
# 3  {'max_depth': 30, 'min_samples_split': 40}         0.345477
# 4  {'max_depth': 30, 'min_samples_split': 50}         0.344748
# 5  {'max_depth': 30, 'min_samples_split': 60}         0.341955
# 6  {'max_depth': 40, 'min_samples_split': 40}         0.345234
# 7  {'max_depth': 40, 'min_samples_split': 50}         0.344869
# 8  {'max_depth': 40, 'min_samples_split': 60}         0.342077
#
#    rank_test_score
# 0                1
# 1                5
# 2                8
# 3                1
# 4                5
# 5                8
# 6                3
# 7                4
# 8                7

# %%
prediction = dtc.predict(X_test)

# %%
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[248 220 243]
#  [236 219 198]
#  [225 205 206]]
# 정확도: 0.3365, 정밀도: 0.3361, 재현율: 0.3360, F1: 0.3360
# ################################################################################

# %% [markdown]
# ### **🚑 SVC**

# %%
l_svc_result_df = pd.DataFrame(g_l_svc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(l_svc_result_df)
# Out:
#         params  mean_test_score  rank_test_score
# 0  {'C': 0.01}         0.338312                1
# 1   {'C': 0.1}         0.334305                2
# 2     {'C': 1}         0.328962                5
# 3    {'C': 10}         0.331755                4
# 4   {'C': 100}         0.334062                3

# %%
svc = g_l_svc.best_estimator_
prediction = g_l_svc.predict(X_test)

# %%
get_evaluation(y_test, prediction, svc, X_test)
# Out:
# 오차 행렬
# [[237 243 231]
#  [190 231 232]
#  [204 219 213]]
# 정확도: 0.3405, 정밀도: 0.3413, 재현율: 0.3407, F1: 0.3404
# ################################################################################

# %% [markdown]
# ### **🚑 KNN**

# %%
result_df = pd.DataFrame(g_knn.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                 params  mean_test_score  rank_test_score
# 0   {'n_neighbors': 3}         0.341591                5
# 1   {'n_neighbors': 5}         0.350091                1
# 2   {'n_neighbors': 7}         0.349120                2
# 3   {'n_neighbors': 9}         0.348998                3
# 4  {'n_neighbors': 11}         0.346205                4

# %%
knn_c = g_knn.best_estimator_
prediction = knn_c.predict(X_test)

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[331 228 152]
#  [300 207 146]
#  [278 200 158]]
# 정확도: 0.3480, 정밀도: 0.3455, 재현율: 0.3437, F1: 0.3398
# ################################################################################

# %% [markdown]
# #### 📊 2Cycle 결과
# best_setimator 을 기준으로 하이퍼 파라미터를 조정하였으나 dtc는 정확도가 하락하였습니다.
# 하지만 cost 값을 높였을 때 svc는 소폭 상승하였으며
# knn은 변화가 없어 svc만 조정하여 스탠다드 스케일링을 진행합니다.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


dtc_parameters = {'dtc__max_depth': [10, 20, 30], 'dtc__min_samples_split': [60, 70, 80]}
l_svc_parameters = {'svc__C': [0.001, 0.01, 0.1, 10, 100]}
knn_parameters = {'knn__n_neighbors': [3, 5, 7, 9, 11]}

dtc = DecisionTreeClassifier()
l_svc = LinearSVC(verbose=True)
knn = KNeighborsClassifier()

dtc_pipe = Pipeline([('standard_scaler', StandardScaler()), ('dtc', dtc)])
g_dtc = GridSearchCV(dtc_pipe, param_grid=dtc_parameters, cv=3, refit=True, return_train_score=True)

svc_pipe = Pipeline([('standard_scaler', StandardScaler()), ('svc', l_svc)])
g_svc = GridSearchCV(svc_pipe, param_grid=l_svc_parameters, cv=3, refit=True, return_train_score=True)

knn_pipe = Pipeline([('standard_scaler', StandardScaler()), ('knn', knn)])
g_knn = GridSearchCV(knn_pipe, param_grid=knn_parameters, cv=3, refit=True, return_train_score=True)

# %%
g_dtc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('dtc', DecisionTreeClassifier())]),
#              param_grid={'dtc__max_depth': [10, 20, 30],
#                          'dtc__min_samples_split': [60, 70, 80]},
#              return_train_score=True)

# %%
g_svc.fit(X_train_over, y_train_over)
# Out:
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('svc', LinearSVC(verbose=True))]),
#              param_grid={'svc__C': [0.001, 0.01, 0.1, 10, 100]},
#              return_train_score=True)

# %%
g_knn.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('knn', KNeighborsClassifier())]),
#              param_grid={'knn__n_neighbors': [3, 5, 7, 9, 11]},
#              return_train_score=True)

# %%
dtc_result_df = pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(dtc_result_df)

dtc = g_dtc.best_estimator_
# Out:
#                                               params  mean_test_score  \
# 0  {'dtc__max_depth': 10, 'dtc__min_samples_split...         0.338919
# 1  {'dtc__max_depth': 10, 'dtc__min_samples_split...         0.336005
# 2  {'dtc__max_depth': 10, 'dtc__min_samples_split...         0.334183
# 3  {'dtc__max_depth': 20, 'dtc__min_samples_split...         0.341834
# 4  {'dtc__max_depth': 20, 'dtc__min_samples_split...         0.338312
# 5  {'dtc__max_depth': 20, 'dtc__min_samples_split...         0.337098
# 6  {'dtc__max_depth': 30, 'dtc__min_samples_split...         0.341712
# 7  {'dtc__max_depth': 30, 'dtc__min_samples_split...         0.338312
# 8  {'dtc__max_depth': 30, 'dtc__min_samples_split...         0.337098
#
#    rank_test_score
# 0                3
# 1                8
# 2                9
# 3                1
# 4                4
# 5                6
# 6                2
# 7                4
# 8                6

# %%
prediction = dtc.predict(X_test)

# %%
get_evaluation(y_test, prediction, dtc, X_test)
# Out:
# 오차 행렬
# [[224 238 249]
#  [209 236 208]
#  [201 214 221]]
# 정확도: 0.3405, 정밀도: 0.3408, 재현율: 0.3413, F1: 0.3405
# ################################################################################

# %%
l_svc_result_df = pd.DataFrame(g_l_svc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(l_svc_result_df)
# Out:
#         params  mean_test_score  rank_test_score
# 0  {'C': 0.01}         0.338312                1
# 1   {'C': 0.1}         0.334305                2
# 2     {'C': 1}         0.328962                5
# 3    {'C': 10}         0.331755                4
# 4   {'C': 100}         0.334062                3

# %%
svc = g_l_svc.best_estimator_
prediction = svc.predict(X_test)

# %%
get_evaluation(y_test, prediction, svc, X_test)
# Out:
# 오차 행렬
# [[237 243 231]
#  [190 231 232]
#  [204 219 213]]
# 정확도: 0.3405, 정밀도: 0.3413, 재현율: 0.3407, F1: 0.3404
# ################################################################################

# %%
result_df = pd.DataFrame(g_knn.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                      params  mean_test_score  rank_test_score
# 0   {'knn__n_neighbors': 3}         0.341105                5
# 1   {'knn__n_neighbors': 5}         0.348148                1
# 2   {'knn__n_neighbors': 7}         0.345598                3
# 3   {'knn__n_neighbors': 9}         0.347298                2
# 4  {'knn__n_neighbors': 11}         0.345355                4

# %%
knn = g_knn.best_estimator_
prediction = knn.predict(X_test)

# %%
get_evaluation(y_test, prediction, knn_c, X_test)
# Out:
# 오차 행렬
# [[305 234 172]
#  [271 253 129]
#  [291 211 134]]
# 정확도: 0.3460, 정밀도: 0.3408, 재현율: 0.3424, F1: 0.3371
# ################################################################################

# %% [markdown]
# #### 📊 3Cycle 결과
# 스탠다드 스케일링을 진행하였을 때, dtc는 소폭 상승하였지만 svc는 변화가 없고, knn은 정확도, 정밀도, 재현율 모두 하락하였습니다.
# dtc만 스탠다드스케일링을 진행합니다.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


dtc_parameters = {'dtc__max_depth': [10, 20, 30], 'dtc__min_samples_split': [60, 70, 80]}
l_svc_parameters = {'C': [0.001, 0.01, 0.1, 10, 100]}
knn_parameters = {'n_neighbors': [3, 5, 7, 9, 11]}

dtc = DecisionTreeClassifier()
l_svc = LinearSVC(verbose=True)
knn = KNeighborsClassifier()

dtc_pipe = Pipeline([('standard_scaler', StandardScaler()), ('dtc', dtc)])
g_dtc = GridSearchCV(dtc_pipe, param_grid=dtc_parameters, cv=3, refit=True, return_train_score=True)

g_l_svc = GridSearchCV(l_svc, param_grid=l_svc_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_knn = GridSearchCV(knn, param_grid=knn_parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)

# %%
g_dtc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('dtc', DecisionTreeClassifier())]),
#              param_grid={'dtc__max_depth': [10, 20, 30],
#                          'dtc__min_samples_split': [60, 70, 80]},
#              return_train_score=True)

# %%
g_l_svc.fit(X_train_over, y_train_over)
# Out:
# [LibLinear]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=3, estimator=LinearSVC(verbose=True), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 10, 100]},
#              return_train_score=True)

# %%
g_knn.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11]},
#              return_train_score=True)

# %%
dtc = g_dtc.best_estimator_
dtc_prediction = dtc.predict(X_test)

# %%
svc = g_l_svc.best_estimator_
svc_prediction = g_l_svc.predict(X_test)

# %%
knn = g_knn.best_estimator_
knn_prediction = knn.predict(X_test)

# %% [markdown]
# ### **🚑 Random Forest**

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier

parameters = {
    'max_depth': [10, 20, 30],
    'min_samples_split': [60, 70, 80, 90]
}

rfc = RandomForestClassifier(n_estimators=100)

features, targets = h_df.iloc[:, :-1], h_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=10, n_jobs=-1)

g_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 30],
#                          'min_samples_split': [60, 70, 80, 90]})

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                         params  mean_test_score  \
# 0   {'max_depth': 10, 'min_samples_split': 60}         0.340125
# 1   {'max_depth': 10, 'min_samples_split': 70}         0.341500
# 2   {'max_depth': 10, 'min_samples_split': 80}         0.335625
# 3   {'max_depth': 10, 'min_samples_split': 90}         0.338500
# 4   {'max_depth': 20, 'min_samples_split': 60}         0.337875
# 5   {'max_depth': 20, 'min_samples_split': 70}         0.338750
# 6   {'max_depth': 20, 'min_samples_split': 80}         0.338875
# 7   {'max_depth': 20, 'min_samples_split': 90}         0.339500
# 8   {'max_depth': 30, 'min_samples_split': 60}         0.342125
# 9   {'max_depth': 30, 'min_samples_split': 70}         0.335875
# 10  {'max_depth': 30, 'min_samples_split': 80}         0.331875
# 11  {'max_depth': 30, 'min_samples_split': 90}         0.338125
#
#     rank_test_score
# 0                 3
# 1                 2
# 2                11
# 3                 7
# 4                 9
# 5                 6
# 6                 5
# 7                 4
# 8                 1
# 9                10
# 10               12
# 11                8

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='macro')
    recall = recall_score(y_test , prediction, average='macro')
    f1 = f1_score(y_test, prediction, average='macro')
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)

# %%
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[308 184 199]
#  [289 180 187]
#  [301 180 172]]
# 정확도: 0.3300, 정밀도: 0.3274, 재현율: 0.3278, F1: 0.3239
# ################################################################################

# %%
from sklearn.inspection import permutation_importance

importance = permutation_importance(rfc, X_test, y_test, n_repeats=30, random_state=124)
importance.importances_mean.argsort()[::-1]
# Out:
# array([1, 0, 3, 5, 4, 2], dtype=int64)

# %%
for i in importance.importances_mean.argsort()[::-1]:
    print(f'{features.columns[i]}: {round(importance.importances_mean[i], 4)}')
# Out:
# Gender: -0.0002
# Age: -0.0014
# Medical Condition: -0.0034
# Medication: -0.0039
# Admission Type: -0.005
# Blood Type: -0.0079

# %% [markdown]
# #### 📊 1Cycle 결과
# 정확도는 높지만 고르게 예측하지 못하므로 적절하지 못한 모델로 판단된다.
# 전체적으로 비율을 맞춰주는 민맥스 스케일러를 사용해본다.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier

parameters = {
    'rfc__max_depth': [10, 20, 30],
    'rfc__min_samples_split': [60, 70, 80, 90]
}

rfc = RandomForestClassifier(n_estimators=100)

features, targets =  h_df.iloc[:, :-1], h_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

rfc_pipe = Pipeline([('min_max_scaler', MinMaxScaler()), ('rfc', rfc)])

g_rfc = GridSearchCV(rfc_pipe, param_grid=parameters, cv=10, n_jobs=-1)

g_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('min_max_scaler', MinMaxScaler()),
#                                        ('rfc', RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'rfc__max_depth': [10, 20, 30],
#                          'rfc__min_samples_split': [60, 70, 80, 90]})

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                                params  mean_test_score  \
# 0   {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.335250
# 1   {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.334125
# 2   {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.331875
# 3   {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.342000
# 4   {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.333625
# 5   {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.336625
# 6   {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.334250
# 7   {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.337125
# 8   {'rfc__max_depth': 30, 'rfc__min_samples_split...         0.337875
# 9   {'rfc__max_depth': 30, 'rfc__min_samples_split...         0.327875
# 10  {'rfc__max_depth': 30, 'rfc__min_samples_split...         0.343000
# 11  {'rfc__max_depth': 30, 'rfc__min_samples_split...         0.338375
#
#     rank_test_score
# 0                 7
# 1                 9
# 2                11
# 3                 2
# 4                10
# 5                 6
# 6                 8
# 7                 5
# 8                 4
# 9                12
# 10                1
# 11                3

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)

# %%
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[334 166 191]
#  [287 183 186]
#  [329 154 170]]
# 정확도: 0.3435, 정밀도: 0.3421, 재현율: 0.3409, F1: 0.3354
# ################################################################################

# %%
from sklearn.inspection import permutation_importance

importance = permutation_importance(rfc, X_test, y_test, n_repeats=30, random_state=124)
importance.importances_mean.argsort()[::-1]
# Out:
# array([0, 3, 5, 2, 1, 4], dtype=int64)

# %%
for i in importance.importances_mean.argsort()[::-1]:
    print(f'{features.columns[i]}: {round(importance.importances_mean[i], 4)}')
# Out:
# Age: 0.0163
# Medical Condition: 0.01
# Medication: 0.0078
# Blood Type: 0.0076
# Gender: 0.004
# Admission Type: 0.0036

# %% [markdown]
# #### 📊 2Cycle 결과

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier

parameters = {
    'rfc__max_depth': [10, 20, 30],
    'rfc__min_samples_split': [60, 70, 80, 90]
}

rfc = RandomForestClassifier(n_estimators=100)

features, targets =  h_df.iloc[:, :-1], h_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

rfc_pipe = Pipeline([('standard_scaler', StandardScaler()), ('rfc', rfc)])

g_rfc = GridSearchCV(rfc_pipe, param_grid=parameters, cv=10, n_jobs=-1)

g_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('standard_scaler', StandardScaler()),
#                                        ('rfc', RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'rfc__max_depth': [10, 20, 30],
#                          'rfc__min_samples_split': [60, 70, 80, 90]})

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                                params  mean_test_score  \
# 0   {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.337375
# 1   {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.335625
# 2   {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.337125
# 3   {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.334000
# 4   {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.334250
# 5   {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.335625
# 6   {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.340625
# 7   {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.339375
# 8   {'rfc__max_depth': 30, 'rfc__min_samples_split...         0.334625
# 9   {'rfc__max_depth': 30, 'rfc__min_samples_split...         0.333375
# 10  {'rfc__max_depth': 30, 'rfc__min_samples_split...         0.335000
# 11  {'rfc__max_depth': 30, 'rfc__min_samples_split...         0.338125
#
#     rank_test_score
# 0                 4
# 1                 7
# 2                 5
# 3                11
# 4                10
# 5                 6
# 6                 1
# 7                 2
# 8                 9
# 9                12
# 10                8
# 11                3

# %%
rfc = g_rfc.best_estimator_
rfc_prediction = rfc.predict(X_test)

# %%
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[334 166 191]
#  [287 183 186]
#  [329 154 170]]
# 정확도: 0.3435, 정밀도: 0.3421, 재현율: 0.3409, F1: 0.3354
# ################################################################################

# %%
from sklearn.inspection import permutation_importance

importance = permutation_importance(rfc, X_test, y_test, n_repeats=30, random_state=124)
importance.importances_mean.argsort()[::-1]
# Out:
# array([0, 3, 5, 2, 1, 4], dtype=int64)

# %%
for i in importance.importances_mean.argsort()[::-1]:
    print(f'{features.columns[i]}: {round(importance.importances_mean[i], 4)}')
# Out:
# Age: 0.0099
# Medical Condition: 0.0093
# Medication: 0.009
# Blood Type: 0.0046
# Gender: 0.002
# Admission Type: -0.0008

# %% [markdown]
# #### 📊 3Cycle 결과
#  랜덤 포레스트의 정확도가 제일 높으나 오차행렬을 보았을때, 정확한 예측을 했다고 보기 어렵다.
#  때문에 적절한 모델이 아니라고 판단되며 다른 모델을 통해 분석을 하여야한다.

# %% [markdown]
# ### **🚑 Boosting - Adaboost**

# %%
from sklearn.ensemble import AdaBoostClassifier

parmeters = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

adabc = AdaBoostClassifier()

g_ada = GridSearchCV(adabc, param_grid=parmeters, cv=5, n_jobs=-1)
g_ada.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 150]})

# %%
result_df = pd.DataFrame(g_ada.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.336248
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.334548
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.329447
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.333455
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.328233
# 5   {'learning_rate': 0.5, 'n_estimators': 150}         0.332848
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.329447
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.330783
# 8   {'learning_rate': 0.7, 'n_estimators': 150}         0.335033
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.331512
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.332726
# 11    {'learning_rate': 1, 'n_estimators': 150}         0.333940
#
#     rank_test_score
# 0                 1
# 1                 3
# 2                10
# 3                 5
# 4                12
# 5                 6
# 6                10
# 7                 9
# 8                 2
# 9                 8
# 10                7
# 11                4

# %%
ada = g_ada.best_estimator_
ada_prediction = ada.predict(X_test)

# %%
get_evaluation(y_test, ada_prediction, ada, X_test)
# Out:
# 오차 행렬
# [[234 261 196]
#  [180 255 221]
#  [219 227 207]]
# 정확도: 0.3480, 정밀도: 0.3482, 재현율: 0.3481, F1: 0.3474
# ################################################################################

# %% [markdown]
# ### **🚑 Boosting - GBM**

# %%
from sklearn.ensemble import GradientBoostingClassifier

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_gbc = GridSearchCV(GradientBoostingClassifier(loss='log_loss'), param_grid=parameters, cv=5)
g_gbc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]})

# %%
result_df = pd.DataFrame(g_gbc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.350577
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.355677
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.361141
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.357256
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.358470
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.356284
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.359320
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.358349
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.357134
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.353491
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.357984
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.361506
#
#     rank_test_score
# 0                12
# 1                10
# 2                 2
# 3                 7
# 4                 4
# 5                 9
# 6                 3
# 7                 5
# 8                 8
# 9                11
# 10                6
# 11                1

# %%
gbc = g_gbc.best_estimator_
gbc_prediction = gbc.predict(X_test)

# %%
get_evaluation(y_test, gbc_prediction, gbc, X_test)
# Out:
# 오차 행렬
# [[390 153 148]
#  [151 372 133]
#  [148 155 350]]
# 정확도: 0.5560, 정밀도: 0.5559, 재현율: 0.5558, F1: 0.5558
# ################################################################################

# %% [markdown]
# ### **🚑 Boosting - XGboost**

# %%
from xgboost import XGBClassifier

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

xgb = XGBClassifier()

g_xgb = GridSearchCV(xgb, 
                     param_grid=parameters, 
                     cv=5, 
                     refit=True, 
                     return_train_score=True, 
                     n_jobs=-1)

g_xgb.fit(X_train_over, y_train_over, early_stopping_rounds=50, eval_set=evals)
# Out:
# [0]	validation_0-mlogloss:1.09072	validation_1-mlogloss:1.09028
# [1]	validation_0-mlogloss:1.08428	validation_1-mlogloss:1.08335
# [2]	validation_0-mlogloss:1.07740	validation_1-mlogloss:1.07766
# [3]	validation_0-mlogloss:1.07142	validation_1-mlogloss:1.07287
# [4]	validation_0-mlogloss:1.06653	validation_1-mlogloss:1.06646
# [5]	validation_0-mlogloss:1.06157	validation_1-mlogloss:1.06077
# [6]	validation_0-mlogloss:1.05716	validation_1-mlogloss:1.05578
# [7]	validation_0-mlogloss:1.05296	validation_1-mlogloss:1.05227
# [8]	validation_0-mlogloss:1.04844	validation_1-mlogloss:1.04721
# [9]	validation_0-mlogloss:1.04366	validation_1-mlogloss:1.04356
# [10]	validation_0-mlogloss:1.03947	validation_1-mlogloss:1.03971
# [11]	validation_0-mlogloss:1.03381	validation_1-mlogloss:1.03513
# [12]	validation_0-mlogloss:1.02997	validation_1-mlogloss:1.03026
# [13]	validation_0-mlogloss:1.02559	validation_1-mlogloss:1.02633
# [14]	validation_0-mlogloss:1.02176	validation_1-mlogloss:1.02275
# [15]	validation_0-mlogloss:1.01743	validation_1-mlogloss:1.01710
# [16]	validation_0-mlogloss:1.01399	validation_1-mlogloss:1.01309
# [17]	validation_0-mlogloss:1.01050	validation_1-mlogloss:1.00874
# [18]	validation_0-mlogloss:1.00752	validation_1-mlogloss:1.00585
# [19]	validation_0-mlogloss:1.00500	validation_1-mlogloss:1.00243
# [20]	validation_0-mlogloss:1.00196	validation_1-mlogloss:0.99974
# [21]	validation_0-mlogloss:0.99879	validation_1-mlogloss:0.99613
# [22]	validation_0-mlogloss:0.99627	validation_1-mlogloss:0.99286
# [23]	validation_0-mlogloss:0.99270	validation_1-mlogloss:0.99037
# [24]	validation_0-mlogloss:0.99034	validation_1-mlogloss:0.98746
# [25]	validation_0-mlogloss:0.98804	validation_1-mlogloss:0.98548
# [26]	validation_0-mlogloss:0.98486	validation_1-mlogloss:0.98291
# [27]	validation_0-mlogloss:0.98200	validation_1-mlogloss:0.97994
# [28]	validation_0-mlogloss:0.97933	validation_1-mlogloss:0.97788
# [29]	validation_0-mlogloss:0.97556	validation_1-mlogloss:0.97452
# [30]	validation_0-mlogloss:0.97318	validation_1-mlogloss:0.97211
# [31]	validation_0-mlogloss:0.97100	validation_1-mlogloss:0.97001
# [32]	validation_0-mlogloss:0.96898	validation_1-mlogloss:0.96795
# [33]	validation_0-mlogloss:0.96582	validation_1-mlogloss:0.96489
# [34]	validation_0-mlogloss:0.96352	validation_1-mlogloss:0.96223
# [35]	validation_0-mlogloss:0.96125	validation_1-mlogloss:0.96026
# [36]	validation_0-mlogloss:0.95911	validation_1-mlogloss:0.95781
# [37]	validation_0-mlogloss:0.95719	validation_1-mlogloss:0.95574
# [38]	validation_0-mlogloss:0.95496	validation_1-mlogloss:0.95331
# C:\ProgramData\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [39]	validation_0-mlogloss:0.95271	validation_1-mlogloss:0.95089
# [40]	validation_0-mlogloss:0.95066	validation_1-mlogloss:0.94896
# [41]	validation_0-mlogloss:0.94808	validation_1-mlogloss:0.94649
# [42]	validation_0-mlogloss:0.94605	validation_1-mlogloss:0.94379
# [43]	validation_0-mlogloss:0.94394	validation_1-mlogloss:0.94157
# [44]	validation_0-mlogloss:0.94186	validation_1-mlogloss:0.94028
# [45]	validation_0-mlogloss:0.93994	validation_1-mlogloss:0.93891
# [46]	validation_0-mlogloss:0.93842	validation_1-mlogloss:0.93757
# [47]	validation_0-mlogloss:0.93566	validation_1-mlogloss:0.93464
# [48]	validation_0-mlogloss:0.93403	validation_1-mlogloss:0.93349
# [49]	validation_0-mlogloss:0.93233	validation_1-mlogloss:0.93160
# [50]	validation_0-mlogloss:0.93136	validation_1-mlogloss:0.93008
# [51]	validation_0-mlogloss:0.92962	validation_1-mlogloss:0.92802
# [52]	validation_0-mlogloss:0.92757	validation_1-mlogloss:0.92667
# [53]	validation_0-mlogloss:0.92583	validation_1-mlogloss:0.92405
# [54]	validation_0-mlogloss:0.92475	validation_1-mlogloss:0.92299
# [55]	validation_0-mlogloss:0.92344	validation_1-mlogloss:0.92209
# [56]	validation_0-mlogloss:0.92150	validation_1-mlogloss:0.91979
# [57]	validation_0-mlogloss:0.91960	validation_1-mlogloss:0.91737
# [58]	validation_0-mlogloss:0.91716	validation_1-mlogloss:0.91364
# [59]	validation_0-mlogloss:0.91565	validation_1-mlogloss:0.91172
# [60]	validation_0-mlogloss:0.91379	validation_1-mlogloss:0.90947
# [61]	validation_0-mlogloss:0.91191	validation_1-mlogloss:0.90707
# [62]	validation_0-mlogloss:0.90997	validation_1-mlogloss:0.90461
# [63]	validation_0-mlogloss:0.90827	validation_1-mlogloss:0.90315
# [64]	validation_0-mlogloss:0.90667	validation_1-mlogloss:0.90104
# [65]	validation_0-mlogloss:0.90438	validation_1-mlogloss:0.89927
# [66]	validation_0-mlogloss:0.90313	validation_1-mlogloss:0.89801
# [67]	validation_0-mlogloss:0.90129	validation_1-mlogloss:0.89571
# [68]	validation_0-mlogloss:0.90042	validation_1-mlogloss:0.89439
# [69]	validation_0-mlogloss:0.89853	validation_1-mlogloss:0.89209
# [70]	validation_0-mlogloss:0.89692	validation_1-mlogloss:0.89053
# [71]	validation_0-mlogloss:0.89573	validation_1-mlogloss:0.88975
# [72]	validation_0-mlogloss:0.89457	validation_1-mlogloss:0.88841
# [73]	validation_0-mlogloss:0.89306	validation_1-mlogloss:0.88760
# [74]	validation_0-mlogloss:0.89110	validation_1-mlogloss:0.88597
# [75]	validation_0-mlogloss:0.88999	validation_1-mlogloss:0.88440
# [76]	validation_0-mlogloss:0.88874	validation_1-mlogloss:0.88315
# [77]	validation_0-mlogloss:0.88729	validation_1-mlogloss:0.88128
# [78]	validation_0-mlogloss:0.88612	validation_1-mlogloss:0.87994
# [79]	validation_0-mlogloss:0.88444	validation_1-mlogloss:0.87773
# [80]	validation_0-mlogloss:0.88273	validation_1-mlogloss:0.87632
# [81]	validation_0-mlogloss:0.88116	validation_1-mlogloss:0.87449
# [82]	validation_0-mlogloss:0.87923	validation_1-mlogloss:0.87314
# [83]	validation_0-mlogloss:0.87767	validation_1-mlogloss:0.87134
# [84]	validation_0-mlogloss:0.87606	validation_1-mlogloss:0.86889
# [85]	validation_0-mlogloss:0.87462	validation_1-mlogloss:0.86696
# [86]	validation_0-mlogloss:0.87291	validation_1-mlogloss:0.86558
# [87]	validation_0-mlogloss:0.87127	validation_1-mlogloss:0.86387
# [88]	validation_0-mlogloss:0.86977	validation_1-mlogloss:0.86273
# [89]	validation_0-mlogloss:0.86890	validation_1-mlogloss:0.86184
# [90]	validation_0-mlogloss:0.86772	validation_1-mlogloss:0.86114
# [91]	validation_0-mlogloss:0.86654	validation_1-mlogloss:0.86000
# [92]	validation_0-mlogloss:0.86511	validation_1-mlogloss:0.85857
# [93]	validation_0-mlogloss:0.86368	validation_1-mlogloss:0.85681
# [94]	validation_0-mlogloss:0.86224	validation_1-mlogloss:0.85498
# [95]	validation_0-mlogloss:0.86130	validation_1-mlogloss:0.85427
# [96]	validation_0-mlogloss:0.85983	validation_1-mlogloss:0.85363
# [97]	validation_0-mlogloss:0.85816	validation_1-mlogloss:0.85298
# [98]	validation_0-mlogloss:0.85694	validation_1-mlogloss:0.85213
# [99]	validation_0-mlogloss:0.85517	validation_1-mlogloss:0.85096
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
result_df = pd.DataFrame(g_xgb.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.355434
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.362113
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.354463
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.355434
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.361020
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.354341
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.357863
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.354463
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.353491
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.351184
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.352763
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.350334
#
#     rank_test_score
# 0                 4
# 1                 1
# 2                 7
# 3                 4
# 4                 2
# 5                 8
# 6                 3
# 7                 6
# 8                 9
# 9                11
# 10               10
# 11               12

# %%
xgb = g_xgb.best_estimator_
xgb_prediction = xgb.predict(X_test)

# %%
get_evaluation(y_test, xgb_prediction, xgb, X_test)
# Out:
# 오차 행렬
# [[443 129 119]
#  [107 419 130]
#  [116 125 412]]
# 정확도: 0.6370, 정밀도: 0.6370, 재현율: 0.6369, F1: 0.6369
# ################################################################################

# %% [markdown]
# ### **🚑 Boosting - LightGBM**

# %%
from lightgbm import LGBMClassifier

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

g_lgbm = GridSearchCV(LGBMClassifier(), param_grid=parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)
g_lgbm.fit(X_train_over, y_train_over, eval_set=evals)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8235, number of used features: 6
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# GridSearchCV(cv=5, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
result_df = pd.DataFrame(g_lgbm.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.359684
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.362477
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.354584
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.357863
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.359320
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.351791
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.361627
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.363206
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.354098
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.361141
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.362234
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.360049
#
#     rank_test_score
# 0                 7
# 1                 2
# 2                10
# 3                 9
# 4                 8
# 5                12
# 6                 4
# 7                 1
# 8                11
# 9                 5
# 10                3
# 11                6

# %%
lgbm = g_lgbm.best_estimator_

lgbm_prediction = lgbm.predict(X_test)

# %%
get_evaluation(y_test, lgbm_prediction, lgbm, X_test)
# Out:
# 오차 행렬
# [[492 106  93]
#  [102 447 107]
#  [ 94 112 447]]
# 정확도: 0.6930, 정밀도: 0.6927, 재현율: 0.6926, F1: 0.6927
# ################################################################################

# %% [markdown]
# ### **🚑 Voting**

# %%
from sklearn.ensemble import VotingClassifier

vc = VotingClassifier(estimators=[
    ('gbc', gbc), ('xgb', xgb), ('lgbm', lgbm)
], voting='soft', n_jobs=-1)

vc.fit(X_train_over, y_train_over)
# Out:
# VotingClassifier(estimators=[('gbc',
#                               GradientBoostingClassifier(learning_rate=1,
#                                                          n_estimators=500)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             grow_poli...
#                                             learning_rate=0.3, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='multi:softprob', ...)),
#                              ('lgbm', LGBMClassifier(learning_rate=0.7))],
#                  n_jobs=-1, voting='soft')

# %%
soft_vc_prediction = vc.predict(X_test)

# %% [markdown]
# #### 📊 soft Voting 결과

# %%
get_evaluation(y_test, prediction, vc, X_test)
# Out:
# 오차 행렬
# [[467 117 107]
#  [110 426 120]
#  [113 115 425]]
# 정확도: 0.6590, 정밀도: 0.6587, 재현율: 0.6587, F1: 0.6587
# ################################################################################

# %%
from sklearn.inspection import permutation_importance

importance = permutation_importance(vc, X_test, y_test, n_repeats=30, random_state=124)
importance.importances_mean.argsort()[::-1]
# Out:
# array([0, 3, 5, 2, 4, 1], dtype=int64)

# %%
for i in importance.importances_mean.argsort()[::-1]:
    print(f'{features.columns[i]}: {round(importance.importances_mean[i], 4)}')
# Out:
# Age: 0.2993
# Medical Condition: 0.1731
# Medication: 0.1687
# Blood Type: 0.1476
# Admission Type: 0.1191
# Gender: 0.0853

# %%
from sklearn.ensemble import VotingClassifier

vc = VotingClassifier(estimators=[
    ('gbc', gbc), ('xgb', xgb), ('lgbm', lgbm)
], voting='hard', n_jobs=-1)

vc.fit(X_train_over, y_train_over)
# Out:
# VotingClassifier(estimators=[('gbc',
#                               GradientBoostingClassifier(learning_rate=1,
#                                                          n_estimators=500)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             grow_poli...
#                                             interaction_constraints=None,
#                                             learning_rate=0.3, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='multi:softprob', ...)),
#                              ('lgbm', LGBMClassifier(learning_rate=0.7))],
#                  n_jobs=-1)

# %%
hard_vc_prediction = vc.predict(X_test)

# %% [markdown]
# #### 📊 hard Voting 결과

# %%
get_evaluation(y_test, prediction, vc, X_test)
# Out:
# 오차 행렬
# [[465 124 102]
#  [123 418 115]
#  [122 124 407]]
# 정확도: 0.6450, 정밀도: 0.6449, 재현율: 0.6445, F1: 0.6445
# ################################################################################

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

dtc_accuracy = accuracy_score(y_test, dtc_prediction)
svc_accuracy = accuracy_score(y_test, svc_prediction)
knn_accuracy = accuracy_score(y_test, knn_prediction)
rfc_accuracy = accuracy_score(y_test, rfc_prediction)

dtc_precision = precision_score(y_test, dtc_prediction, average='macro')
svc_precision = precision_score(y_test, svc_prediction, average='macro')
knn_precision = precision_score(y_test, knn_prediction, average='macro')
rfc_precision = precision_score(y_test, rfc_prediction, average='macro')

dtc_recall = recall_score(y_test, dtc_prediction, average='macro')
svc_recall = recall_score(y_test, svc_prediction, average='macro')
knn_recall = recall_score(y_test, knn_prediction, average='macro')
rfc_recall = recall_score(y_test, rfc_prediction, average='macro')

dtc_f1 = f1_score(y_test, dtc_prediction, average='macro')
svc_f1 = f1_score(y_test, svc_prediction, average='macro')
knn_f1 = f1_score(y_test, knn_prediction, average='macro')
rfc_f1 = f1_score(y_test, rfc_prediction, average='macro')

models = ['DTC', 'SVC', 'KNN', 'RFC']
accuracy_scores = [dtc_accuracy, svc_accuracy, knn_accuracy, rfc_accuracy]
precisions = [dtc_precision, svc_precision, knn_precision, rfc_precision]
recalls = [dtc_recall, svc_recall, knn_recall, rfc_recall]
f1_scores = [dtc_f1, svc_f1, knn_f1, rfc_f1]

# %%
data = {
    'Model': models * 4,
    'Score': accuracy_scores + precisions + recalls + f1_scores,
    'Metric': ['Accuracy'] * len(models) + ['Precision'] * len(models) + ['Recall'] * len(models) + ['F1 Score'] * len(models)
}

df = pd.DataFrame(data)

palette = sns.color_palette("coolwarm")

sns.barplot(data=df, x='Model', y='Score', hue='Metric', palette=palette)

plt.title('Evaluation Score Comparison')
plt.xlabel('Model')
plt.ylabel('Score')
plt.legend(bbox_to_anchor=(1.05, 1.0))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

s_vc_accuracy = accuracy_score(y_test, soft_vc_prediction)
h_vc_accuracy = accuracy_score(y_test, hard_vc_prediction)
ada_accuracy = accuracy_score(y_test, ada_prediction)
gbc_accuracy = accuracy_score(y_test, gbc_prediction)
xgb_accuracy = accuracy_score(y_test, xgb_prediction)
lgbm_accuracy = accuracy_score(y_test, lgbm_prediction)

s_vc_precision = precision_score(y_test, soft_vc_prediction, average='macro')
h_vc_precision = precision_score(y_test, hard_vc_prediction, average='macro')
ada_precision = precision_score(y_test, ada_prediction, average='macro')
gbc_precision = precision_score(y_test, gbc_prediction, average='macro')
xgb_precision = precision_score(y_test, xgb_prediction, average='macro')
lgbm_precision = precision_score(y_test, lgbm_prediction, average='macro')

s_vc_recall = recall_score(y_test, soft_vc_prediction, average='macro')
h_vc_recall = recall_score(y_test, hard_vc_prediction, average='macro')
ada_recall = recall_score(y_test, ada_prediction, average='macro')
gbc_recall = recall_score(y_test, gbc_prediction, average='macro')
xgb_recall = recall_score(y_test, xgb_prediction, average='macro')
lgbm_recall = recall_score(y_test, lgbm_prediction, average='macro')

s_vc_f1 = f1_score(y_test, soft_vc_prediction, average='macro')
h_vc_f1 = f1_score(y_test, hard_vc_prediction, average='macro')
ada_f1 = f1_score(y_test, ada_prediction, average='macro')
gbc_f1 = f1_score(y_test, gbc_prediction, average='macro')
xgb_f1 = f1_score(y_test, xgb_prediction, average='macro')
lgbm_f1 = f1_score(y_test, lgbm_prediction, average='macro')

models = ['SOFT_VC', 'HARD_VC', 'ADA', 'GBC', 'XGB', 'LGBM']
accuracy_scores = [s_vc_accuracy, h_vc_accuracy, ada_accuracy, gbc_accuracy, xgb_accuracy, lgbm_accuracy]
precisions = [s_vc_precision, h_vc_precision, ada_precision, gbc_precision, xgb_precision, lgbm_precision]
recalls = [s_vc_recall, h_vc_recall, ada_recall, gbc_recall, xgb_recall, lgbm_recall]
f1_scores = [s_vc_f1, h_vc_f1, ada_f1, gbc_f1, xgb_f1, lgbm_f1]

# %%
data = {
    'Model': models * 4,
    'Score': accuracy_scores + precisions + recalls + f1_scores,
    'Metric': ['Accuracy'] * len(models) + ['Precision'] * len(models) + ['Recall'] * len(models) + ['F1 Score'] * len(models)
}

df = pd.DataFrame(data)
palette = sns.color_palette("coolwarm")

sns.barplot(data=df, x='Model', y='Score', hue='Metric', palette=palette)

plt.title('Evaluation Score Comparison')
plt.xlabel('Model')
plt.ylabel('Score')
plt.legend(bbox_to_anchor=(1.05, 1.0))
plt.show()

# %% [markdown]
# ### **🚑 결론**

# %% [markdown]
# <img src="./images/health_plt01.png" width="400px"> <img src="./images/health_plt02.png" width="550px">

# %% [markdown]
# **Light gradient boosting 모델의 성능이 가장 높게 나타나므로 lgbm이 가장 적합한 모델이라 판단됩니다.**

# %%
# 앞쪽은 정확도가 낮은데 0.3 부스팅에서 높아진 이유 설명 : 반복 합습을 ㅌㅇ한 상승
